# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mql = pd.read_csv("olist_marketing_qualified_leads_dataset.csv")
deals = pd.read_csv("olist_closed_deals_dataset.csv")

mql.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mql = pd.read_csv("olist_marketing_qualified_leads_dataset.csv")
#       2 deals = pd.read_csv("olist_closed_deals_dataset.csv")
#       4 mql.head()
#
# NameError: name 'pd' is not defined
